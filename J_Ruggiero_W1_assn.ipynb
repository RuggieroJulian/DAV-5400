# %% [markdown]
# # Week 1 Assignment
#
# ##### Link to my Github copy that contains the data (I already included the column names at the top of the file)
#
# https://github.com/gitjuli/DAV-5400/blob/master/breast-cancer-wisconsin.data
#
# #### Link to the original dataset general information:
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Original%29
#
# #### The data file can be found here (breast-cancer-wisconsin.data file):
# https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/
#
# #### The dataset names with further information can be found here:
# https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.names
#
# For the week 1 assignemnt I will use the breast-cancer-wisconsin data. I am interested in this dataset because it provides with valuable information related to the breast cancer cell, such as its size, shape and class. Despite there are some missing values, there are only 16 instances, denoted by "?", it also contains a good amount of records (699).
# My goal is to be able to answer these questions:
#
# - Percentage of the cases that are benign and malign?
# - For the malign cases, which is the cell behaviour in terms of its shape and size?
# - What about the benign ones? which is their behaviour?
# - Which are the main characteristics that differenciate a benign from a malign tumor?
#
# Below I just tried to take a quick look at the dataset inside a pandas dataframe to be sure that I would be able to answer the questions above (I added the columns title I got from the breast-cancer-wisconsin.names file)

# %%
import pandas as pd
url="https://raw.githubusercontent.com/gitjuli/DAV-5400/master/breast-cancer-wisconsin.csv" #using dataset raw data
df=pd.read_csv(url) #loading the data inside a dataframe

# %%
df.head() #a quick look to the first 5 rows of data to see how it looks like
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...
